# %%
import image_analysis as ia

# %% [markdown]
# ## synthetic image example

# %%
impath_b = 'Example Images/fig1_b.png'
impath_c = 'Example Images/fig1_c.png'
impath_d = 'Example Images/fig1_d_correct.png'
impath_e = 'Example Images/fig1_e_correct.png'

# %%
import pandas as pd

# Get IDs and standard deviations
ID_b, s_b = ia.indiv_ID(impath_b, 4)
ID_c, s_c = ia.indiv_ID(impath_c, 4)
ID_d, s_d = ia.indiv_ID(impath_d, 4)
ID_e, s_e = ia.indiv_ID(impath_e, 4)

# Create a list of dictionaries for each row
data = [
    {'Image': 'b', 'ID': ID_b[0], 's': s_b[0]},
    {'Image': 'c', 'ID': ID_c[0], 's': s_c[0]},
    {'Image': 'd', 'ID': ID_d[0], 's': s_d[0]},
    {'Image': 'e', 'ID': ID_e[0], 's': s_e[0]}
]

# Create DataFrame
synthetic_img_ID = pd.DataFrame(data)

# Display table
synthetic_img_ID
# Out:
#   Image        ID         s
# 0     b  0.746936  0.139089
# 1     c  0.734770  0.136486
# 2     d  0.361039  0.067275
# 3     e  0.347717  0.064712

# %%
ia.thresh_curve_indiv_img('Example Images/Img1.tif', 4)
# Out:
#                 ID       std  thresh
# filename
# Img1.tif  0.008971  0.012188    0.95
# Img1.tif  0.009614  0.013774    0.94
# Img1.tif  0.010315  0.015280    0.93
# Img1.tif  0.011090  0.016970    0.92
# Img1.tif  0.011737  0.018684    0.91
# Img1.tif  0.012421  0.020195    0.90
# Img1.tif  0.016108  0.028317    0.85
# Img1.tif  0.018573  0.034933    0.80
# Img1.tif  0.019368  0.040092    0.75
# Img1.tif  0.018639  0.042725    0.70
# Img1.tif  0.016791  0.043918    0.65
# Img1.tif  0.014954  0.044196    0.60
# Img1.tif  0.012752  0.043474    0.55
# Img1.tif  0.010833  0.042119    0.50

# %% [markdown]
# ## SEM images from Li||Li symmetric cells (Fig. 5)

# %%
# 3a) 3mAh and 1cycle 
df3_1 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_1c/1000_cropped', no_slices=4)

# 3b) 3mAh and 10cycle 
df3_10 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_10c/1000_cropped', no_slices=4)

# 3c) 3mAh and 50cycle 
df3_50 = ia.thresh_folder('//Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_50c/1000_cropped', no_slices=4)

# 3d) 3mAh and 100cycle 
df3_100 = ia.thresh_folder('//Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_100c/1000_cropped', no_slices=4)

# 3e) 3mAh and 125cycle 
df3_125 = ia.thresh_folder('//Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_125c/1000_cropped', no_slices=4)

# 3f) 3mAh and 150cycle 
df3_150 = ia.thresh_folder('//Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_150c/1000_cropped', no_slices=4)

# 3g) 3mAh and 175cycle 
df3_175 = ia.thresh_folder('//Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/3mAh_175c/1000_cropped', no_slices=4)

# %% [markdown]
# # thresh curve

# %%
df3_1 = ia.summarize_max_id(df3_1, 1)
df3_10 = ia.summarize_max_id(df3_10, 10)
df3_50 = ia.summarize_max_id(df3_50, 50)
df3_100 = ia.summarize_max_id(df3_100, 100)
df3_125 = ia.summarize_max_id(df3_125, 125)
df3_150 = ia.summarize_max_id(df3_150, 150)
df3_175 = ia.summarize_max_id(df3_175, 175)

# %%
# 6a) 6mAh and 1cycle 
df6_1 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_1c/1000_cropped', no_slices=4)

# 6b) 6mAh and 10cycle 
df6_10 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_10c/1000_cropped', no_slices=4)

# 6c) 6mAh and 50cycle 
df6_50 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_50c/1000_cropped', no_slices=4)

# 6d) 6mAh and 55cycle 
df6_55 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_55c/1000_cropped', no_slices=4)

# 6e) 6mAh and 58cycle 
df6_58 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_58c/1000_cropped', no_slices=4)

# 6f) 6mAh and short 
df6_short = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/6mAh_short/1000_cropped', no_slices=4)

###


# 8a) 8mAh and 1cycle 
df8_1 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_1c/1000_cropped', no_slices=4)

# 8b) 8mAh and 10cycle 
df8_10 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_10c/1000_cropped', no_slices=4)

# 8c) 8mAh and 30cycle 
df8_30 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_30c/1000_cropped', no_slices=4)

# 8d) 8mAh and 31cycle 
df8_31 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_31c/1000_cropped', no_slices=4)

# 8e) 8mAh and 33cycle 
df8_33 = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_33c/1000_cropped', no_slices=4)

# 8f) 8mAh and short 
df8_short = ia.thresh_folder('/Users/jennynicolas/Library/CloudStorage/OneDrive-UCSanDiego/SEM Images/Matrix Test/8mAh_short/1000_cropped', no_slices=4)

# %%
df6_1 = ia.summarize_max_id(df6_1, 1)
df6_10 = ia.summarize_max_id(df6_10, 10)
df6_50 = ia.summarize_max_id(df6_50, 50)
df6_55 = ia.summarize_max_id(df6_55, 55)
df6_58 = ia.summarize_max_id(df6_58, 58)

df8_1 = ia.summarize_max_id(df8_1, 1)
df8_10 = ia.summarize_max_id(df8_10, 10)
df8_30 = ia.summarize_max_id(df8_30, 30)
df8_31 = ia.summarize_max_id(df8_31, 31)
df8_33 = ia.summarize_max_id(df8_33, 33)

# %%
df_list = ([df3_1, df3_10, df3_50, df3_100, df3_125, df3_150, df3_175])
combined_df = ia.append_dataframes(df_list)
combined_df
# Out:
#    condition  avg_max_ID  std_max_ID
# 0          1    0.214704    0.155881
# 1         10    0.237633    0.056318
# 2         50    0.269870    0.120424
# 3        100    0.420842    0.155122
# 4        125    0.461484    0.310019
# 5        150    0.468336    0.404689
# 6        175    0.370710    0.235800

# %%
df_list = ([df6_1, df6_10, df6_50, df6_55, df6_58])
combined_df_6mah = ia.append_dataframes(df_list)
combined_df_6mah

df_list = ([df8_1, df8_10, df8_30, df8_31, df8_33])
combined_df_8mah = ia.append_dataframes(df_list)
combined_df_8mah
# Out:
#    condition  avg_max_ID  std_max_ID
# 0          1    0.114226    0.021100
# 1         10    0.207812    0.100233
# 2         30    0.301404    0.157234
# 3         31    0.253762    0.117483
# 4         33    0.297506    0.065058

# %%
dataframes = [combined_df]
labels = ['3 mAh/cm²']
colors = ['#386cb0', '#7570b3', '#66a61e']
markers = ['o']
output = "Example Image.pdf"

ia.plot_stacked_id_vs_cycle(dataframes, labels, colors, markers, title="ID_plot", output_path=output)

# %%
dataframes = [combined_df, combined_df_6mah, combined_df_8mah]
labels = ['3 mAh/cm²', '6 mAh/cm²', '8 mAh/cm²']
colors = ['#386cb0', '#7570b3', '#66a61e']
markers = ['o', 's', '^']
output = "Example Image.pdf"

ia.plot_stacked_id_vs_cycle(dataframes, labels, colors, markers, title="ID_plot", output_path=output)
