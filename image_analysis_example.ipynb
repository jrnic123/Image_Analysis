# %%
import image_analysis as ia

# %%
impath = '/Users/jennynicolas/Desktop/Pure Cu/70.tif'
df_threshold = ia.thresh_curve(impath, 16)

# %%
thresh_quantile = [50, 45, 40, 35, 30, 25, 20, 15, 10, 9, 8, 7, 6, 5]
 

ia.analyze_curve(df_threshold, thresh_quantile)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /var/folders/_t/m9gxbjkd3zg6vvs0vndlt4gr0000gn/T/ipykernel_78575/2789227534.py in <module>
#       2
#       3
# ----> 4 ia.analyze_curve(df_threshold, thresh_quantile)
#
# ~/Library/CloudStorage/OneDrive-UCSanDiego/(1) PIL_Image_Processing/image_analysis.py in analyze_curve(df, thresh_quantile)
#     178
#     179     plt.plot(x, y)
# --> 180     plt.errorbar(x, y, yerr=e, linestyle='none', marker='.', markersize=10)
#     181     plt.title('3D Reconstruction by varying FC')
#     182     plt.xlabel('% Brightest Pixels')
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2562         uplims=False, xlolims=False, xuplims=False, errorevery=1,
# ...
